# %% [markdown]
# # 02 - Build Vector Index
# This notebook loads local docs, chunks them, embeds chunks, and saves index artifacts.

# %%
from offline_ollama_rag.config import get_settings
from offline_ollama_rag.ollama_client import AsyncOllamaGateway
from offline_ollama_rag.pipeline import build_index
settings = get_settings()
gateway = AsyncOllamaGateway(settings.ollama_host)

# %%
index_info = await build_index(settings, gateway)
index_info
# Out:
# 2026-06-12 16:49:07.549 | INFO     | offline_ollama_rag.pipeline:build_index:57 - Embedding 5 chunks with embeddinggemma:latest
# 2026-06-12 16:49:08.019 | INFO     | offline_ollama_rag.pipeline:build_index:66 - Index built with 5 chunks and dimension 768
# {'n_documents': 5,
#  'n_chunks': 5,
#  'embedding_dimension': 768,
#  'embeddings_file': '/home/ahmad/AI/Projects/offline-ollama-rag-app/artifacts/index/embeddings.npy',
#  'chunks_file': '/home/ahmad/AI/Projects/offline-ollama-rag-app/artifacts/index/chunks.json'}
